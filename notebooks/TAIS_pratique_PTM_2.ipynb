# %% [markdown]
# Le notebook et les données sont à récupérer à partir de : https://github.com/PSIG-EHESS/TAIS

# %%
import pandas as pd
import os

# %%
# !git clone https://github.com/PSIG-EHESS/TAIS.git
# Out:
# fatal: destination path 'TAIS' already exists and is not an empty directory.

# %%
csv_folder = "TAIS/donnees/"
df_1898 = pd.read_csv(csv_folder + "ptm_1898_augmentee.csv")
print("1898:" + str(len(df_1898)))
print(list(df_1898))
# Out:
# 1898:82978
# ['nOrder', 'num_voie', 'code_voie', 'code_voie_quartier', 'nom_voie', 'type_voie', 'quartiers', 'voie_fantome', 'lettre', 'pdf', 'pagination', 'NUM', 'NUM_GLOB', 'PART', 'PERS', 'ORG', 'STATUT', 'VILLE', 'VOIE', 'RUE', 'NUM_PERS', 'GER', 'LOC', 'SPATIAL', 'Liste_imm', 'Nb_imm']
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pd.set_option('display.max_rows', 500)
from IPython.display import display, HTML
display(df_1898)
# Out:
#        nOrder  num_voie code_voie         code_voie_quartier  nom_voie  \
# 0           2       2.0       A.2  A.2 ABBAYE (Rue de l') 24    ABBAYE
# 1           3       2.0       A.2  A.2 ABBAYE (Rue de l') 24    ABBAYE
# 2           4       2.0       A.2  A.2 ABBAYE (Rue de l') 24    ABBAYE
# 3           5       2.0       A.2  A.2 ABBAYE (Rue de l') 24    ABBAYE
# 4           6       2.0       A.2  A.2 ABBAYE (Rue de l') 24    ABBAYE
# ...       ...       ...       ...                        ...       ...
# 82973   82975       1.0       Z.1      Z.1 ZACHARIE (Rue) 20  ZACHARIE
# 82974   82976       1.0       Z.1      Z.1 ZACHARIE (Rue) 20  ZACHARIE
# 82975   82977       1.0       Z.1      Z.1 ZACHARIE (Rue) 20  ZACHARIE
# 82976   82978       1.0       Z.1      Z.1 ZACHARIE (Rue) 20  ZACHARIE
# 82977   82979       1.0       Z.1      Z.1 ZACHARIE (Rue) 20  ZACHARIE
#
#       type_voie quartiers voie_fantome lettre    pdf  ...  STATUT  \
# 0           rue        24          NaN      A    1.0  ...     NaN
# 1           rue        24          NaN      A    1.0  ...   C. de
# 2           rue        24          NaN      A    1.0  ...     NaN
# 3           rue        24          NaN      A    1.0  ...     NaN
# 4           rue        24          NaN      A    1.0  ...     NaN
# ...         ...       ...          ...    ...    ...  ...     ...
# 82973       rue        20          NaN      Z  915.0  ...     NaN
# 82974       rue        20          NaN      Z  915.0  ...     NaN
# 82975       rue        20          NaN      Z  915.0  ...     NaN
# 82976       rue        20          NaN      Z  915.0  ...     NaN
# 82977       rue        20          NaN      Z  915.0  ...     NaN
#
#                 VILLE  VOIE                    RUE NUM_PERS  GER    LOC  \
# 0                 NaN   NaN                    NaN      NaN  NaN    NaN
# 1               Paris   pl.  St-1 Germain-des-Prés        3  NaN    NaN
# 2               Paris    r.                 Abbaye       13  NaN    NaN
# 3                 NaN   NaN                    NaN      NaN  NaN    NaN
# 4                 NaN   NaN                    NaN      NaN  NaN    NaN
# ...               ...   ...                    ...      ...  ...    ...
# 82973           Paris    r.              Vert bois       13  NaN    NaN
# 82974           Paris    r.               Zacharie       18  NaN    NaN
# 82975  Vne-St-Hilaire    r.                 Balzac       10  NaN  Seine
# 82976           Paris    r.            Amster¬ dam       91  NaN    NaN
# 82977             NaN   NaN                    NaN      NaN  NaN    NaN
#
#                                 SPATIAL        Liste_imm Nb_imm
# 0      Entrée pass. Petite-Boucherie, 1            ['1']      1
# 1                                   NaN  ['3', '5', '7']      3
# 2                                   NaN     ['11', '13']      2
# 3                  Entrée r. Rennes, 44     ['17', '19']      2
# 4                 Entrée r. Echaudé, 18            ['2']      1
# ...                                 ...              ...    ...
# 82973                               NaN           ['16']      1
# 82974                               NaN           ['18']      1
# 82975                               NaN           ['20']      1
# 82976                               NaN           ['22']      1
# 82977          Entrée r. St-Séverin, 26           ['24']      1
#
# [82978 rows x 26 columns]

# %%
df_1898_sub = df_1898.loc[:, df_1898.columns.isin(['TITRE', 'NUM', 'PERS', 'PRENOM', 'ORG', 'STATUT', 'VILLE', 'Liste_imm', 'nom_voie', 'type_voie'])]
df_1898_sub
# Out:
#        nom_voie type_voie    NUM                  PERS  ORG STATUT  \
# 0        ABBAYE       rue      1                   NaN  NaN    NaN
# 1        ABBAYE       rue  3 à 7         Laguibourgère  NaN  C. de
# 2        ABBAYE       rue  11-13               Vallois  NaN    NaN
# 3        ABBAYE       rue  17-19                   NaN  NaN    NaN
# 4        ABBAYE       rue      2                   NaN  NaN    NaN
# ...         ...       ...    ...                   ...  ...    ...
# 82973  ZACHARIE       rue     16              Vangasse  NaN    NaN
# 82974  ZACHARIE       rue     18                Renaud  NaN    NaN
# 82975  ZACHARIE       rue     20                Rousse  NaN    NaN
# 82976  ZACHARIE       rue     22  Hureau de Villeneuve  NaN    NaN
# 82977  ZACHARIE       rue     24                   NaN  NaN    NaN
#
#                 VILLE        Liste_imm
# 0                 NaN            ['1']
# 1               Paris  ['3', '5', '7']
# 2               Paris     ['11', '13']
# 3                 NaN     ['17', '19']
# 4                 NaN            ['2']
# ...               ...              ...
# 82973           Paris           ['16']
# 82974           Paris           ['18']
# 82975  Vne-St-Hilaire           ['20']
# 82976           Paris           ['22']
# 82977             NaN           ['24']
#
# [82978 rows x 8 columns]

# %%
 df_1898_sub_geoloc = df_1898_sub.sample(frac=0.010, random_state=1) 
 df_1898_sub_geoloc
 # % du total
 #seed 1, nous utilisons random_state qui est en quelque sorte un nombre "noyau" pour le générateur de nombres aléatoires et permet d'assurer la reproductibilité des exemples.
# Out:
#                      nom_voie type_voie NUM              PERS  \
# 31110                 FROCHOT       rue   6             Jauze
# 65618             ROI D'ALGER       rue   5            Bellet
# 27797   FAUBOURG POISSONNIÈRE       rue   6              Jean
# 62975                RANELAGH       rue  16             Fabre
# 48494                  MERLIN       rue  26             Bigot
# ...                       ...       ...  ..               ...
# 28021  FAUBOURG SAINT-ANTOINE       rue  16  Lhuillier-Samson
# 30327       FOSSES-ST-JACQUES       rue  16               NaN
# 19806             CORDELIÈRES       rue   6          Weilquez
# 65366            ROCHECHOUART       rue  59          Cochelin
# 34709                   GUYOT       rue  34               NaN
#
#                     ORG STATUT         VILLE Liste_imm
# 31110               NaN    NaN      St-Mandé     ['6']
# 65618               NaN    NaN     Vincennes     ['5']
# 27797               NaN    NaN  Neuilly s/S.     ['6']
# 62975               NaN    NaN         Paris    ['16']
# 48494            Constr    NaN         Paris    ['26']
# ...                 ...    ...           ...       ...
# 28021               NaN    Vve         Paris    ['16']
# 30327  Casel et Lesieur    NaN         Paris    ['16']
# 19806               NaN    NaN         Paris     ['6']
# 65366               NaN    NaN      St-Cloud    ['59']
# 34709               NaN    NaN           NaN    ['34']
#
# [830 rows x 8 columns]

# %%
len(df_1898_sub_geoloc)
# Out:
# 830

# %% [markdown]
# Utilisation de l'API BAN : https://adresse.data.gouv.fr/api-doc/adresse
#
# Paramètres d'entrée
# * q : requete
# * lat : latitude en WGS84
# * lon : longuitude en WGS84
# * autocomplete : recherche d'alternatives
# * limit : nombre limite de résultats
# * city : donner une priorité géographique par le nom de la ville
# * postcode : donner une priorité géographique par le code postal
# * citycode (code INSEE) : idem, avec le code INSEE
#
# La sorties est sérialisée en GeoJSON, les attributs retournés sont :
#
# * id : identifiant de l’adresse (clef d’interopérabilité)
# * geometry : ponctuel exprimé en WGS-84 (EPSG 4326)
# * type : type de résultat trouvé
# * housenumber : numéro « à la plaque »
# * street : position « à la voie », placé approximativement au centre de celle-ci
# * locality : lieu-dit
# * municipality : numéro « à la commune »
# * score : valeur de 0 à 1 indiquant la pertinence du résultat
# * housenumber : numéro avec indice de répétition éventuel (bis, ter, A, B)
# * street : nom de la voie
# * name : numéro éventuel et nom de voie ou lieu dit
# * postcode : code postal
# * citycode : code INSEE de la commune
# * city : nom de la commune
# * district : nom de l’arrondissement (Paris/Lyon/Marseille)
# * oldcitycode : code INSEE de la commune ancienne (le cas échéant)
# * oldcity : nom de la commune ancienne (le cas échéant)
# * context : n° de département, nom de département et de région
# * label : libellé complet de l’adresse
# * x : coordonnées géographique en projection légale (Lambert 93)
# * y : coordonnées géographique en projection légale (Lambert 93)
# * importance : indicateur d’importance (champ technique)

# %%
# 18 rue Abbé de l'épée
# !curl "https://api-adresse.data.gouv.fr/search/?q=18%20rue%20de%20l'ABB%C3%89%20DE%20L'%C3%89P%C3%89E&autocomplete=1"
# Out:
# {"type":"FeatureCollection","version":"draft","features":[{"type":"Feature","geometry":{"type":"Point","coordinates":[3.874244,43.621544]},"properties":{"label":"18 Rue de l'Abbé de l'Epée 34090 Montpellier","score":0.8840618181818181,"housenumber":"18","id":"34172_0025_00018","name":"18 Rue de l'Abbé de l'Epée","postcode":"34090","citycode":"34172","x":770583.97,"y":6280667.94,"city":"Montpellier","context":"34, Hérault, Occitanie","type":"housenumber","importance":0.72468,"street":"Rue de l'Abbé de l'Epée"}},{"type":"Feature","geometry":{"type":"Point","coordinates":[0.32002,46.569141]},"properties":{"label":"18 Rue de l'Abbe de l'Epée 86000 Poitiers","score":0.88103,"housenumber":"18","id":"86194_0010_00018","name":"18 Rue de l'Abbe de l'Epée","postcode":"86000","citycode":"86194","x":494773.01,"y":6611161.57,"city":"Poitiers","context":"86, Vienne, Nouvelle-Aquitaine","type":"housenumber","importance":0.69133,"street":"Rue de l'Abbe de l'Epée"}},{"type":"Feature","geometry":{"type":"Point","coordinates":[3.159611,50.715638]},"properties":{"label":"18 Rue de l'Abbé de l'Epée 59200 Tourcoing","score":0.8790754545454545,"housenumber":"18","id":"59599_0029_00018","name":"18 Rue de l'Abbé de l'Epée","postcode":"59200","citycode":"59599","x":711292.98,"y":7068778.84,"city":"Tourcoing","context":"59, Nord, Hauts-de-France","type":"housenumber","importance":0.66983,"street":"Rue de l'Abbé de l'Epée"}},{"type":"Feature","geometry":{"type":"Point","coordinates":[2.339927,48.843821]},"properties":{"label":"18 Rue de l'Abbé de l'Epée 75005 Paris","score":0.8775072727272727,"housenumber":"18","id":"75105_0006_00018","name":"18 Rue de l'Abbé de l'Epée","postcode":"75005","citycode":"75105","x":651556.66,"y":6860621.81,"city":"Paris","district":"Paris 5e Arrondissement","context":"75, Paris, Île-de-France","type":"housenumber","importance":0.65258,"street":"Rue de l'Abbé de l'Epée"}},{"type":"Feature","geometry":{"type":"Point","coordinates":[-0.866419,47.059802]},"properties":{"label":"18 Rue de l’Abbe de l’Epee 49300 Cholet","score":0.874380909090909,"housenumber":"18","id":"49099_kd45gc_00018","name":"18 Rue de l’Abbe de l’Epee","postcode":"49300","citycode":"49099","oldcitycode":"49099","x":406646.86,"y":6669356.58,"city":"Cholet","oldcity":"Cholet","context":"49, Maine-et-Loire, Pays de la Loire","type":"housenumber","importance":0.61819,"street":"Rue de l’Abbe de l’Epee"}}],"attribution":"BAN","licence":"ETALAB-2.0","query":"18 rue de l'ABBÉ DE L'ÉPÉE","limit":5}

# %% [markdown]
# Sortie en GeoJson : https://geojson.org/
#
#
# ```
# {"type":"FeatureCollection",
#   "features":[
#
#     {"type":"Feature",
#     "geometry":{"type":"Point","coordinates":[3.874244,43.621544]},
#     "properties":
#       {"label":"18 Rue de l'Abbé de l'Epée 34090 Montpellier",
#       "score":0.8840618181818181,
#       "housenumber":"18",
#       "id":"34172_0025_00018",
#       "name":"18 Rue de l'Abbé de l'Epée",
#       "postcode":"34090",
#       "citycode":"34172",
#       "x":770583.97,
#       "y":6280667.94,
#       "city":"Montpellier",
#       "context":"34, Hérault, Occitanie",
#       "type":"housenumber","
#       importance":0.72468,
#       "street":"Rue de l'Abbé de l'Epée"}},
#
#     {"type":"Feature",
#     "geometry":{"type":"Point","coordinates":[0.32002,46.569141]},
#     "properties":
#       {"label":"18 Rue de l'Abbe de l'Epée 86000 Poitiers",
#       "score":0.88103,
#       "housenumber":"18",
#       "id":"86194_0010_00018",
#       "name":"18 Rue de l'Abbe de l'Epée",
#       "postcode":"86000",
#       "citycode":"86194",
#       "x":494773.01,
#       "y":6611161.57,
#       "city":"Poitiers",
#       "context":"86, Vienne, Nouvelle-Aquitaine",
#       "type":"housenumber",
#       "importance":0.69133,
#       "street":"Rue de l'Abbe de l'Epée"}},
#
#       ...
#
#       {"type":"Feature",
#       "geometry":{"type":"Point","coordinates":[2.339927,48.843821]},
#       "properties":{
#         "label":"18 Rue de l'Abbé de l'Epée 75005 Paris",
#         "score":0.8775072727272727,
#         "housenumber":"18",
#         "id":"75105_0006_00018",
#         "name":"18 Rue de l'Abbé de l'Epée",
#         "postcode":"75005",
#         "citycode":"75105",
#         "x":651556.66,
#         "y":6860621.81,
#         "city":"Paris",
#         "district":"Paris 5e Arrondissement",
#         "context":"75, Paris, Île-de-France",
#         "type":"housenumber",
#         "importance":0.65258,
#         "street":"Rue de l'Abbé de l'Epée"}},
#
#         ...],
#     "attribution":"BAN",
#     "licence":"ETALAB-2.0",
#     "query":"18 rue de l'ABBÉ DE L'ÉPÉE",
#     "limit":5}
#
# ```

# %%
df_1898_sub_geoloc['addr_complet'] = df_1898_sub_geoloc['NUM'] + " " + df_1898_sub_geoloc['type_voie'] + " " + df_1898_sub_geoloc['nom_voie'] 
df_1898_sub_geoloc
# Out:
#                      nom_voie type_voie NUM              PERS  \
# 31110                 FROCHOT       rue   6             Jauze
# 65618             ROI D'ALGER       rue   5            Bellet
# 27797   FAUBOURG POISSONNIÈRE       rue   6              Jean
# 62975                RANELAGH       rue  16             Fabre
# 48494                  MERLIN       rue  26             Bigot
# ...                       ...       ...  ..               ...
# 28021  FAUBOURG SAINT-ANTOINE       rue  16  Lhuillier-Samson
# 30327       FOSSES-ST-JACQUES       rue  16               NaN
# 19806             CORDELIÈRES       rue   6          Weilquez
# 65366            ROCHECHOUART       rue  59          Cochelin
# 34709                   GUYOT       rue  34               NaN
#
#                     ORG STATUT         VILLE Liste_imm  \
# 31110               NaN    NaN      St-Mandé     ['6']
# 65618               NaN    NaN     Vincennes     ['5']
# 27797               NaN    NaN  Neuilly s/S.     ['6']
# 62975               NaN    NaN         Paris    ['16']
# 48494            Constr    NaN         Paris    ['26']
# ...                 ...    ...           ...       ...
# 28021               NaN    Vve         Paris    ['16']
# 30327  Casel et Lesieur    NaN         Paris    ['16']
# 19806               NaN    NaN         Paris     ['6']
# 65366               NaN    NaN      St-Cloud    ['59']
# 34709               NaN    NaN           NaN    ['34']
#
#                         addr_complet
# 31110                  6 rue FROCHOT
# 65618              5 rue ROI D'ALGER
# 27797    6 rue FAUBOURG POISSONNIÈRE
# 62975                16 rue RANELAGH
# 48494                  26 rue MERLIN
# ...                              ...
# 28021  16 rue FAUBOURG SAINT-ANTOINE
# 30327       16 rue FOSSES-ST-JACQUES
# 19806              6 rue CORDELIÈRES
# 65366            59 rue ROCHECHOUART
# 34709                   34 rue GUYOT
#
# [830 rows x 9 columns]

# %% [markdown]
# PB : adresses mal formées !
# On ne peut que traiter les adresses sur un numéro ou bien utliser la colonne (interpretée) list_immbl.

# %%
df_1898_sub_geoloc['NUM'].str.isnumeric()
# Out:
# 31110    True
# 65618    True
# 27797    True
# 62975    True
# 48494    True
#          ...
# 28021    True
# 30327    True
# 19806    True
# 65366    True
# 34709    True
# Name: NUM, Length: 830, dtype: bool

# %%
df_1898_sub_geoloc_single_num = df_1898_sub_geoloc[df_1898_sub_geoloc['NUM'].str.isnumeric()]
df_1898_sub_geoloc_single_num
# Out:
#                      nom_voie type_voie NUM              PERS  \
# 31110                 FROCHOT       rue   6             Jauze
# 65618             ROI D'ALGER       rue   5            Bellet
# 27797   FAUBOURG POISSONNIÈRE       rue   6              Jean
# 62975                RANELAGH       rue  16             Fabre
# 48494                  MERLIN       rue  26             Bigot
# ...                       ...       ...  ..               ...
# 28021  FAUBOURG SAINT-ANTOINE       rue  16  Lhuillier-Samson
# 30327       FOSSES-ST-JACQUES       rue  16               NaN
# 19806             CORDELIÈRES       rue   6          Weilquez
# 65366            ROCHECHOUART       rue  59          Cochelin
# 34709                   GUYOT       rue  34               NaN
#
#                     ORG STATUT         VILLE Liste_imm  \
# 31110               NaN    NaN      St-Mandé     ['6']
# 65618               NaN    NaN     Vincennes     ['5']
# 27797               NaN    NaN  Neuilly s/S.     ['6']
# 62975               NaN    NaN         Paris    ['16']
# 48494            Constr    NaN         Paris    ['26']
# ...                 ...    ...           ...       ...
# 28021               NaN    Vve         Paris    ['16']
# 30327  Casel et Lesieur    NaN         Paris    ['16']
# 19806               NaN    NaN         Paris     ['6']
# 65366               NaN    NaN      St-Cloud    ['59']
# 34709               NaN    NaN           NaN    ['34']
#
#                         addr_complet
# 31110                  6 rue FROCHOT
# 65618              5 rue ROI D'ALGER
# 27797    6 rue FAUBOURG POISSONNIÈRE
# 62975                16 rue RANELAGH
# 48494                  26 rue MERLIN
# ...                              ...
# 28021  16 rue FAUBOURG SAINT-ANTOINE
# 30327       16 rue FOSSES-ST-JACQUES
# 19806              6 rue CORDELIÈRES
# 65366            59 rue ROCHECHOUART
# 34709                   34 rue GUYOT
#
# [682 rows x 9 columns]

# %%
#construire la requete pour chaque adresse

base_url = "https://api-adresse.data.gouv.fr/search/?"
    
df_1898_sub_geoloc_single_num['ban_query'] = base_url + "q" + "=" + df_1898_sub_geoloc_single_num['addr_complet'].str.replace(" ", "+").str.lower() + "&" + "city=paris" +  "&" + "limit=10"

df_1898_sub_geoloc_single_num['ban_query'].values.tolist()
# Out:
# <ipython-input-106-02e053b1be00>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1898_sub_geoloc_single_num['ban_query'] = base_url + "q" + "=" + df_1898_sub_geoloc_single_num['addr_complet'].str.replace(" ", "+").str.lower() + "&" + "city=paris" +  "&" + "limit=10"
# ['https://api-adresse.data.gouv.fr/search/?q=6+rue+frochot&city=paris&limit=10',
#  "https://api-adresse.data.gouv.fr/search/?q=5+rue+roi+d'alger&city=paris&limit=10",
#  'https://api-adresse.data.gouv.fr/search/?q=6+rue+faubourg+poissonnière&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=16+rue+ranelagh&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=26+rue+merlin&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=2+rue+meyerbeer&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=10+place+nation&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=22+rue+pavillons&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=80+rue+amandiers&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=11+rue+godefroy-cavaignac&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=25+rue+tholozé&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=8+passage+sainte-catherine&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=11+rue+lyon&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=21+rue+billancourt&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=5+rue+chéroy&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=48+rue+lapérouse&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=119+place+cambronne&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=5+rue+gardes&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=15+rue+debelleyme&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=23+rue+téhéran&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=5+rue+naples&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q
city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=1+rue+arquebusiers&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=11+rue+jacques+kablé&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=103+boulevard+malesherbes&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=147+boulevard+lefebvre&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=48+rue+petites-écuries&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=104+boulevard+diderot&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=7+rue+titon&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=198+rue+saint-maur&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=1+rue+chapelle&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=197+rue+faubourg+st-honoré&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=100+rue+provence&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=101+rue+saint-martin&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=46+rue+roussin&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=7+boulevard+diderot&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=6+rue+gauthey&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=9+rue+tibre&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=16+rue+faubourg+saint-antoine&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=16+rue+fosses-st-jacques&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=6+rue+cordelières&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=59+rue+rochechouart&city=paris&limit=10',
#  'https://api-adresse.data.gouv.fr/search/?q=34+rue+guyot&city=paris&limit=10']

# %%
#on prépare les paramètres de la requete et on interroge le service 
import requests, json

ban_api_df = df_1898_sub_geoloc_single_num.copy()

def get_corrds(requet):
  lat, lng, score, postcode, label = None, None, None, None, None
  r = requests.get(requet)
  print(r.status_code)
  if r.status_code not in range(200, 299):
    return None, None, None, None, None
  try:
    #print(r.json())
    results = r.json()['features']
    for result in results:
      if result['properties']['city'] == "Paris":
        lat = result['geometry']['coordinates'][1]
        lng = result['geometry']['coordinates'][0]
        score = result['properties']['score']
        postcode = result['properties']['postcode']
        label = result['properties']['label']
        #print(results)
  except:
    pass
  return lat, lng, score, postcode, label            

def enrich_with_geocoding_api(row):
  column_name = 'ban_query'
  address_value = row[column_name]
  print(address_value)
  address_lat, address_lng, resp_score, resp_postcode, resp_label = get_corrds(address_value)
  row['lat'] = address_lat
  row['lng'] = address_lng
  row['score_resp']	= resp_score
  row['postcode_resp'] = resp_postcode
  row['label_resp'] = resp_label
  #print(row)
  return row

ban_api_df = ban_api_df.apply(enrich_with_geocoding_api, axis=1) # axis=1 is important to use the row itself
ban_api_df
# Out:
# https://api-adresse.data.gouv.fr/search/?q=6+rue+frochot&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=5+rue+roi+d'alger&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=6+rue+faubourg+poissonnière&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=16+rue+ranelagh&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=26+rue+merlin&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=2+rue+meyerbeer&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=10+place+nation&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=22+rue+pavillons&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=80+rue+amandiers&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=11+rue+godefroy-cavaignac&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=25+rue+tholozé&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=8+passage+sainte-catherine&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=11+rue+lyon&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=21+rue+billancourt&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=5+rue+chéroy&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=48+rue+lapérouse&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=119+place+cambronne&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=5+rue+gardes&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=15+rue+debelleyme&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=23+rue+téhéran&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=5+rue+naples&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=65+rue+ménilmontant&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=3+rue+portes+blanches&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=157+rue+legendre&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=1+impasse+boileau&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=13+cloître+saint-honoré&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=20+rue+aqueduc&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=303+rue+charenton&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=34+passage+montgallet&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=25+rue+claude+bernard&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=33+rue+bretagne&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=89+rue+commerce&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=3+rue+michelet&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=3+rue+quinault&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=15+chemin+périchaux&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=4+rue+pétraroue&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=55+rue+villette&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=348+rue+saint-honoré&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=294+rue+vauouelin&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=63+avenue+saint-mande&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=19+rue+saint-roch&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=17+rue+écoles&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=1+rue+gomboust&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=7+passage+amandiers&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=44+rue+cler&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=9+rue+blondel&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=43+rue+claude+bernard&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=15+rue+cléry&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=2+rue+suger&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=14+rue+tanneries&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=7+rue+legendre&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=13+rue+chatelain&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=13+rue+pot+de+fer&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=8+rue+delaitre&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=4+place+nation&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=2+rue+blondel&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=15+rue+michel-ange&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=7+cité+beauharnais&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=126+boulevard+voltaire&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=33+rue+maronites&city=paris&limit=10
# 200
# https://api-adresse.data.gouv.fr/search/?q=15
#
#                         addr_complet  \
# 31110                  6 rue FROCHOT
# 65618              5 rue ROI D'ALGER
# 27797    6 rue FAUBOURG POISSONNIÈRE
# 62975                16 rue RANELAGH
# 48494                  26 rue MERLIN
# ...                              ...
# 28021  16 rue FAUBOURG SAINT-ANTOINE
# 30327       16 rue FOSSES-ST-JACQUES
# 19806              6 rue CORDELIÈRES
# 65366            59 rue ROCHECHOUART
# 34709                   34 rue GUYOT
#
#                                                ban_query        lat       lng  \
# 31110  https://api-adresse.data.gouv.fr/search/?q=6+r...  48.881325  2.337625
# 65618  https://api-adresse.data.gouv.fr/search/?q=5+r...  48.895599  2.347499
# 27797  https://api-adresse.data.gouv.fr/search/?q=6+r...  48.876922  2.348719
# 62975  https://api-adresse.data.gouv.fr/search/?q=16+...  48.855616  2.268344
# 48494  https://api-adresse.data.gouv.fr/search/?q=26+...  48.860508  2.385536
# ...                                                  ...        ...       ...
# 28021  https://api-adresse.data.gouv.fr/search/?q=16+...  48.850530  2.382285
# 30327  https://api-adresse.data.gouv.fr/search/?q=16+...  48.845507  2.344231
# 19806  https://api-adresse.data.gouv.fr/search/?q=6+r...  48.835309  2.348573
# 65366  https://api-adresse.data.gouv.fr/search/?q=59+...        NaN       NaN
# 34709  https://api-adresse.data.gouv.fr/search/?q=34+...        NaN       NaN
#
#        score_resp postcode_resp                                   label_resp
# 31110    0.875509         75009                    6 Rue Frochot 75009 Paris
# 65618    0.468250         75018         5 Passage du Roi d'Alger 75018 Paris
# 27797    0.742433         75009     Rue du Faubourg Poissonnière 75009 Paris
# 62975    0.394805         75016               Square du Ranelagh 75016 Paris
# 48494    0.885087         75011                    26 Rue Merlin 75011 Paris
# ...           ...           ...                                          ...
# 28021    0.731927         75011    Rue du Faubourg Saint-Antoine 75011 Paris
# 30327    0.640506         75005  16 Rue des Fossés Saint-Jacques 75005 Paris
# 19806    0.722515         75013            6 Rue des Cordelières 75013 Paris
# 65366         NaN          None                                         None
# 34709         NaN          None                                         None
#
# [682 rows x 15 columns]

# %% [markdown]
# NB : le score prend essentiellement en compte la portion du texte cherché présente dans l’adresse du référentiel + un peu de levenshtein pour tenir compte de l’ordre (celui ci gère mieux les cas comme « Avenue de Paris Saint-Mandé » / « Avenue de Saint Mande Paris »). Le score est aussi ajusté en cas de préférence géographique (lat/lon) en réduisant la valeur « importance »
# (https://addok.readthedocs.io/en/latest/faq/)

# %%
ban_api_df.to_csv('ban_output_input_682addr.csv', index=False)

# %%
#en cas de problèmes réseau avec l'API, décommenter la ligne  
#ban_api_df = pd.read_csv('ban_output_input_682addr.csv')  
# pour plus d'informations : https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html

# %%
ban_api_df.isnull().sum()
# Out:
# nom_voie           0
# type_voie          0
# NUM                0
# PERS             156
# ORG              652
# STATUT           567
# VILLE            148
# Liste_imm          0
# addr_complet       0
# ban_query          0
# lat              105
# lng              105
# score_resp       105
# postcode_resp    105
# label_resp       105
# dtype: int64

# %%
#https://geopandas.org/

# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.8/dist-packages (0.12.1)
# Requirement already satisfied: pyproj>=2.6.1.post1 in
# 750000063.0  POLYGON ((2.27098 48.87877, 2.27749 48.87796, ...
# 750000069.0  POLYGON ((2.34022 48.89311, 2.33992 48.89212, ...
# 750000020.0  POLYGON ((2.34924 48.84452, 2.34888 48.84449, ...
# 750000033.0  POLYGON ((2.33923 48.87679, 2.33816 48.87686, ...
# 750000034.0  POLYGON ((2.33545 48.87683, 2.33710 48.87671, ...
# 750000003.0  POLYGON ((2.33947 48.86214, 2.33912 48.86148, ...
# 750000014.0  POLYGON ((2.36376 48.85568, 2.36294 48.85456, ...
# 750000025.0  POLYGON ((2.32213 48.84925, 2.32054 48.84842, ...
# 750000038.0  POLYGON ((2.35534 48.87126, 2.35426 48.86933, ...
# 750000001.0  POLYGON ((2.34459 48.85405, 2.34459 48.85405, ...
# 750000073.0  POLYGON ((2.37050 48.87820, 2.37028 48.87799, ...

# %%
gdf_quartier["geometry"].plot(figsize=(16, 16))

# %%
gdf_addr_paris_1898 = geopandas.GeoDataFrame(
    ban_api_df, geometry=geopandas.points_from_xy(ban_api_df.lng, ban_api_df.lat))

# %%
gdf_addr_paris_1898.crs = "EPSG:4326"
gdf_quartier.crs = "EPSG:4326"

gdf_addr_paris_1898.to_crs("EPSG:3857")
gdf_quartier.to_crs("EPSG:3857")
# Out:
#              c_qu  c_quinsee                       l_qu  c_ar      n_sq_ar  \
# n_sq_qu
# 750000013.0  13.0  7510401.0                Saint-Merri   4.0  750000004.0
# 750000016.0  16.0  7510404.0                 Notre-Dame   4.0  750000004.0
# 750000028.0  28.0  7510704.0               Gros-Caillou   7.0  750000007.0
# 750000041.0  41.0  7511101.0            Folie-Méricourt  11.0  750000011.0
# 750000007.0   7.0  7510203.0                       Mail   2.0  750000002.0
# 750000049.0  49.0  7511301.0                Salpêtrière  13.0  750000013.0
# 750000008.0   8.0  7510204.0             Bonne-Nouvelle   2.0  750000002.0
# 750000004.0   4.0  7510104.0              Place-Vendôme   1.0  750000001.0
# 750000050.0  50.0  7511302.0                       Gare  13.0  750000013.0
# 750000076.0  76.0  7511904.0                     Combat  19.0  750000019.0
# 750000070.0  70.0  7511802.0               Clignancourt  18.0  750000018.0
# 750000080.0  80.0  7512004.0                   Charonne  20.0  750000020.0
# 750000071.0  71.0  7511803.0                Goutte-d'Or  18.0  750000018.0
# 750000060.0  60.0  7511504.0                      Javel  15.0  750000015.0
# 750000048.0  48.0  7511204.0              Quinze-Vingts  12.0  750000012.0
# 750000027.0  27.0  7510703.0            Ecole-Militaire   7.0  750000007.0
# 750000059.0  59.0  7511503.0                   Grenelle  15.0  750000015.0
# 750000061.0  61.0  7511601.0                    Auteuil  16.0  750000016.0
# 750000036.0  36.0  7510904.0               Rochechouart   9.0  750000009.0
# 750000047.0  47.0  7511203.0                      Bercy  12.0  750000012.0
# 750000002.0   2.0  7510102.0                     Halles   1.0  750000001.0
# 750000019.0  19.0  7510503.0               Val-de-Grâce   5.0  750000005.0
# 750000058.0  58.0  7511502.0                     Necker  15.0  750000015.0
# 750000079.0  79.0  7512003.0              Père-Lachaise  20.0  750000020.0
# 750000040.0  POLYGON ((264098.135 6253865.328, 264227.107 6...
# 750000077.0  POLYGON ((265299.582 6252340.642, 265289.490 6...
# 750000065.0  POLYGON ((255482.642 6253471.354, 255482.639 6...
# 750000017.0  POLYGON ((262148.717 6248395.543, 262148.141 6...
# 750000031.0  POLYGON ((258821.285 6252592.373, 258781.521 6...
# 750000078.0  POLYGON ((268704.467 6252968.946, 268706.206 6...
# 750000063.0  POLYGON ((252804.834 6254316.906, 253529.091 6...
# 750000069.0  POLYGON ((260511.740 6256743.006, 260478.296 6...
# 750000020.0  POLYGON ((261516.706 6248520.128, 261476.634 6...
# 750000033.0  POLYGON ((260401.731 6253981.490, 260282.394 6...
# 750000034.0  POLYGON ((259981.114 6253987.888, 260164.693 6...
# 750000003.0  POLYGON ((260428.149 6251500.935, 260390.032 6...
# 750000014.0  POLYGON ((263133.072 6250408.071, 263041.637 6...
# 750000025.0  POLYGON ((258498.720 6249320.831, 258321.460 6...
# 750000038.0  POLYGON ((262195.776 6253045.529, 262075.089 6...
# 750000001.0  POLYGON ((260998.942 6250132.905, 260998.863 6...
# 750000073.0  POLYGON ((263882.703 6254219.331, 263857.977 6...

# %%
ax = gdf_quartier.plot(figsize = (25, 22), color='white', edgecolor='black')

gdf_addr_paris_1898.plot(ax = ax, color='orange')

# %% [markdown]
# Les relations spatiales sont définies par l'OGC comme des prédicats binaires (intersects, contains, within, equals, ...) entre les différents types de géométries (point, lignes, polygones).
# Voir toutes les combinaisons possibles dans ce tableau : https://docs.safe.com/fme/html/FME_Desktop_Documentation/FME_Transformers/Transformers/spatialrelations.htm

# %%
joined_df = geopandas.sjoin(
    gdf_addr_paris_1898,
    gdf_quartier,
    how='inner',
    op='intersects',
) 
joined_df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
#                nom_voie type_voie  NUM        PERS              ORG STATUT  \
# 31110           FROCHOT       rue    6       Jauze              NaN    NaN
# 31140         FROMENTIN       rue    1         NaN              NaN    NaN
# 24037             DOUAI       rue   20    Guichard              NaN    NaN
# 3948             AUMALE       rue  560         NaN              NaN    NaN
# 11689         BRUXELLES       rue   40  Goeuneutte              NaN    NaN
# ...                 ...       ...  ...         ...              ...    ...
# 61824          PROVENCE       rue   35         NaN              NaN    NaN
# 43880           LINCOLN       rue   13         NaN              NaN    NaN
# 58869    PIERRE CHARRON       rue   25         NaN  Sté Electricité    NaN
# 19020          COLONNES       rue    2     Boulant              NaN    NaN
# 11873  BUISSON-St-LOUIS       rue   34         NaN              NaN    NaN
#
#                     VILLE Liste_imm             addr_complet  \
# 31110            St-Mandé     ['6']            6 rue FROCHOT
# 31140                 NaN     ['1']          1 rue FROMENTIN
# 24037              Meudon    ['20']             20 rue DOUAI
# 3948                  NaN   ['560']           560 rue AUMALE
# 11689              Auvers    ['40']         40 rue BRUXELLES
# ...                   ...       ...                      ...
# 61824                 NaN    ['35']          35 rue PROVENCE
# 43880                 NaN    ['13']           13 rue LINCOLN
# 58869               Paris    ['25']    25 rue PIERRE CHARRON
# 19020  St-Germain-en-Laye     ['2']           2 rue COLONNES
# 11873                 NaN    ['34']  34 rue BUISSON-St-LOUIS
#
#                                                ban_query  ...  \
# 31110  https://api-adresse.data.gouv.fr/search/?q=6+r...  ...
# 31140  https://api-adresse.data.gouv.fr/search/?q=1+r...  ...
# 24037  https://api-adresse.data.gouv.fr/search/?q=20+...  ...
# 3948   https://api-adresse.data.gouv.fr/search/?q=560...  ...
# 11689  https://api-adresse.data.gouv.fr/search/?q=40+...  ...
# ...                                                  ...  ...
# 61824  https://api-adresse.data.gouv.fr/search/?q=35+...  ...
# 43880  https://api-adresse.data.gouv.fr/search/?q=13+...  ...
# 58869  https://api-adresse.data.gouv.fr/search/?q=25+...  ...
# 19020  https://api-adresse.data.gouv.fr/search/?q=2+r...  ...
# 11873  https://api-adresse.data.gouv.fr/search/?q=34+...  ...
#
#                                        label_resp                  geometry  \
# 31110                   6 Rue Frochot 75009 Paris  POINT (2.33763 48.88132)
# 31140                 1 Rue Fromentin 75009 Paris  POINT (2.33433 48.88214)
# 24037                 20 Rue de Douai 75009 Paris  POINT (2.33460 48.88187)
# 3948                     Rue d'Aumale 75009 Paris  POINT (2.33593 48.87818)
# 11689             40 Rue de Bruxelles 75009 Paris  POINT (2.32834 48.88290)
# ...                                           ...                       ...
# 61824              35 Rue de Provence 75009 Paris  POINT (2.33825 48.87410)
# 43880                  13 Rue Lincoln 75008 Paris  POINT (2.30306 48.87066)
# 58869              Rue Pierre Charron 75008 Paris  POINT (2.30316 48.86933)
# 19020              2 Rue des Colonnes 75002 Paris  POINT (2.33953 48.86919)
# 11873  Passage du Buisson Saint-Louis 75010 Paris  POINT (2.37308 48.87249)
#
#        index_right  c_qu  c_quinsee                 l_qu  c_ar      n_sq_ar  \
# 31110  750000033.0  33.0  7510901.0        Saint-Georges   9.0  750000009.0
# 31140  750000033.0  33.0  7510901.0        Saint-Georges   9.0  750000009.0
# 24037  750000033.0  33.0  7510901.0        Saint-Georges   9.0  750000009.0
# 3948   750000033.0  33.0  7510901.0        Saint-Georges   9.0  750000009.0
# 11689  750000033.0  33.0  7510901.0        Saint-Georges   9.0  750000009.0
# ...            ...   ...        ...                  ...   ...          ...
# 61824  750000035.0  35.0  7510903.0  Faubourg-Montmartre   9.0  750000009.0
# 43880  750000029.0  29.0  7510801.0       Champs-Elysées   8.0  750000008.0
# 58869  750000029.0  29.0  7510801.0       Champs-Elysées   8.0  750000008.0
# 19020  750000006.0   6.0  7510202.0             Vivienne   2.0  750000002.0
# 11873  750000040.0  40.0  7511004.0  Hôpital-Saint-Louis  10.0  750000010.0
#
#          perimetre       surface
# 31110  3429.188334  7.170916e+05
# 31140  3429.188334  7.170916e+05
# 24037  3429.188334  7.170916e+05
# 3948   3429.188334  7.170916e+05
# 11689  3429.188334  7.170916e+05
# ...            ...           ...
# 61824  2786.541926  4.173351e+05
# 43880  5480.652870  1.140254e+06
# 58869  5480.652870  1.140254e+06
# 19020  2058.472959  2.435508e+05
# 11873  4453.177991  8.837260e+05
#
# [577 rows x 24 columns]

# %%
non_match_addr = geopandas.sjoin(
    gdf_addr_paris_1898,
    gdf_quartier,
    how='left',
    op='intersects',
) 
non_match_addr
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3249: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):
#                      nom_voie type_voie NUM              PERS  \
# 31110                 FROCHOT       rue   6             Jauze
# 65618             ROI D'ALGER       rue   5            Bellet
# 27797   FAUBOURG POISSONNIÈRE       rue   6              Jean
# 62975                RANELAGH       rue  16             Fabre
# 48494                  MERLIN       rue  26             Bigot
# ...                       ...       ...  ..               ...
# 28021  FAUBOURG SAINT-ANTOINE       rue  16  Lhuillier-Samson
# 30327       FOSSES-ST-JACQUES       rue  16               NaN
# 19806             CORDELIÈRES       rue   6          Weilquez
# 65366            ROCHECHOUART       rue  59          Cochelin
# 34709                   GUYOT       rue  34               NaN
#
#                     ORG STATUT         VILLE Liste_imm  \
# 31110               NaN    NaN      St-Mandé     ['6']
# 65618               NaN    NaN     Vincennes     ['5']
# 27797               NaN    NaN  Neuilly s/S.     ['6']
# 62975               NaN    NaN         Paris    ['16']
# 48494            Constr    NaN         Paris    ['26']
# ...                 ...    ...           ...       ...
# 28021               NaN    Vve         Paris    ['16']
# 30327  Casel et Lesieur    NaN         Paris    ['16']
# 19806               NaN    NaN         Paris     ['6']
# 65366               NaN    NaN      St-Cloud    ['59']
# 34709               NaN    NaN           NaN    ['34']
#
#                         addr_complet  \
# 31110                  6 rue FROCHOT
# 65618              5 rue ROI D'ALGER
# 27797    6 rue FAUBOURG POISSONNIÈRE
# 62975                16 rue RANELAGH
# 48494                  26 rue MERLIN
# ...                              ...
# 28021  16 rue FAUBOURG SAINT-ANTOINE
# 30327       16 rue FOSSES-ST-JACQUES
# 19806              6 rue CORDELIÈRES
# 65366            59 rue ROCHECHOUART
# 34709                   34 rue GUYOT
#
#                                                ban_query  ...  \
# 31110  https://api-adresse.data.gouv.fr/search/?q=6+r...  ...
# 65618  https://api-adresse.data.gouv.fr/search/?q=5+r...  ...
# 27797  https://api-adresse.data.gouv.fr/search/?q=6+r...  ...
# 62975  https://api-adresse.data.gouv.fr/search/?q=16+...  ...
# 48494  https://api-adresse.data.gouv.fr/search/?q=26+...  ...
# ...                                                  ...  ...
# 28021  https://api-adresse.data.gouv.fr/search/?q=16+...  ...
# 30327  https://api-adresse.data.gouv.fr/search/?q=16+...  ...
# 19806  https://api-adresse.data.gouv.fr/search/?q=6+r...  ...
# 65366  https://api-adresse.data.gouv.fr/search/?q=59+...  ...
# 34709  https://api-adresse.data.gouv.fr/search/?q=34+...  ...
#
#                                         label_resp                  geometry  \
# 31110                    6 Rue Frochot 75009 Paris  POINT (2.33763 48.88132)
# 65618         5 Passage du Roi d'Alger 75018 Paris  POINT (2.34750 48.89560)
# 27797     Rue du Faubourg Poissonnière 75009 Paris  POINT (2.34872 48.87692)
# 62975               Square du Ranelagh 75016 Paris  POINT (2.26834 48.85562)
# 48494                    26 Rue Merlin 75011 Paris  POINT (2.38554 48.86051)
# ...                                            ...                       ...
# 28021    Rue du Faubourg Saint-Antoine 75011 Paris  POINT (2.38228 48.85053)
# 30327  16 Rue des Fossés Saint-Jacques 75005 Paris  POINT (2.34423 48.84551)
# 19806            6 Rue des Cordelières 75013 Paris  POINT (2.34857 48.83531)
# 65366                                         None               POINT EMPTY
# 34709                                         None               POINT EMPTY
#
#        index_right  c_qu  c_quinsee               l_qu  c_ar      n_sq_ar  \
# 31110  750000033.0  33.0  7510901.0      Saint-Georges   9.0  750000009.0
# 65618  750000070.0  70.0  7511802.0       Clignancourt  18.0  750000018.0
# 27797  750000036.0  36.0  7510904.0       Rochechouart   9.0  750000009.0
# 62975  750000062.0  62.0  7511602.0             Muette  16.0  750000016.0
# 48494  750000043.0  43.0  7511103.0           Roquette  11.0  750000011.0
# ...            ...   ...        ...                ...   ...          ...
# 28021  750000044.0  44.0  7511104.0  Sainte-Marguerite  11.0  750000011.0
# 30327  750000019.0  19.0  7510503.0       Val-de-Grâce   5.0  750000005.0
# 19806  750000052.0  52.0  7511304.0        Croulebarbe  13.0  750000013.0
# 65366          NaN   NaN        NaN                NaN   NaN          NaN
# 34709          NaN   NaN        NaN                NaN   NaN          NaN
#
#           perimetre       surface
# 31110   3429.188334  7.170916e+05
# 65618   6005.520389  1.653715e+06
# 27797   2862.450525  5.004354e+05
# 62975  11962.438594  5.477898e+06
# 48494   4973.010557  1.172087e+06
# ...             ...           ...
# 28021   4591.310799  9.296092e+05
# 30327   3485.831358  7.036312e+05
# 19806   3289.230480  6.920677e+05
# 65366           NaN           NaN
# 34709           NaN           NaN
#
# [682 rows x 24 columns]
# Warning: Total number of columns (24) exceeds max_columns (20) limiting to first (20) columns.

# %%
non_match_addr.isnull().sum()
# Out:
# nom_voie           0
# type_voie          0
# NUM                0
# PERS             156
# ORG              652
# STATUT           567
# VILLE            148
# Liste_imm          0
# addr_complet       0
# ban_query          0
# lat              105
# lng              105
# score_resp       105
# postcode_resp    105
# label_resp       105
# geometry           0
# index_right      105
# c_qu             105
# c_quinsee        105
# l_qu             105
# c_ar             105
# n_sq_ar          105
# perimetre        105
# surface          105
# dtype: int64

# %%
count_addr_per_quartier = joined_df.groupby(['n_sq_ar'], 
    as_index=False,
)['addr_complet'].count()
count_addr_per_quartier.columns = ['n_sq_ar', 'count_addr']  # rename the column
count_addr_per_quartier
# Out:
#         n_sq_ar  count_addr
# 0   750000001.0          17
# 1   750000002.0          17
# 2   750000003.0          19
# 3   750000004.0          20
# 4   750000005.0          31
# 5   750000006.0          24
# 6   750000007.0          18
# 7   750000008.0          34
# 8   750000009.0          23
# 9   750000010.0          20
# 10  750000011.0          34
# 11  750000012.0          32
# 12  750000013.0          28
# 13  750000014.0          15
# 14  750000015.0          40
# 15  750000016.0          38
# 16  750000017.0          61
# 17  750000018.0          47
# 18  750000019.0          17
# 19  750000020.0          42

# %%
addr_count_quartier = gdf_quartier.merge(
    count_addr_per_quartier, 
    on='n_sq_ar', 
    how='left', 
)  # merge left back to nyc_community_districts layer
addr_count_quartier.head()
# Out:
#    c_qu  c_quinsee             l_qu  c_ar      n_sq_ar    perimetre  \
# 0  13.0  7510401.0      Saint-Merri   4.0  750000004.0  2346.004687
# 1  16.0  7510404.0       Notre-Dame   4.0  750000004.0  3283.163371
# 2  28.0  7510704.0     Gros-Caillou   7.0  750000007.0  4720.994373
# 3  41.0  7511101.0  Folie-Méricourt  11.0  750000011.0  3724.352694
# 4   7.0  7510203.0             Mail   2.0  750000002.0  2179.153605
#
#         surface                                           geometry  count_addr
# 0  3.130404e+05  POLYGON ((2.35262 48.85491, 2.35249 48.85467, ...          20
# 1  3.782522e+05  POLYGON ((2.36131 48.84858, 2.36151 48.84823, ...          20
# 2  1.381893e+06  POLYGON ((2.30954 48.85396, 2.30646 48.85413, ...          18
# 3  7.257525e+05  POLYGON ((2.37010 48.86376, 2.36690 48.86246, ...          34
# 4  2.781426e+05  POLYGON ((2.34684 48.86491, 2.34668 48.86443, ...          17

# %%
addr_count_quartier.isnull().sum()
# Out:
# c_qu          0
# c_quinsee     0
# l_qu          0
# c_ar          0
# n_sq_ar       0
# perimetre     0
# surface       0
# geometry      0
# count_addr    0
# dtype: int64

# %%
addr_count_quartier['count_addr'].fillna(
    0, 
    inplace=True,
)  
# fill in missing's with 0, valid in this case.

# %%
addr_count_quartier.plot(
    column='count_addr', 
    figsize=(16, 9),
    cmap='OrRd', #cmap='magma'
    legend=True,
)

# schema de couleurs : https://matplotlib.org/2.0.2/users/colormaps.html

# %%
addr_count_quartier.plot(column='count_addr', scheme='Quantiles', k=5, figsize=(16, 9), cmap='OrRd', legend=True)

# %%
addr_count_quartier['count_addr'].describe()

# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html
# Out:
# count    80.000000
# mean     28.850000
# std      12.022237
# min      15.000000
# 25%      18.750000
# 50%      26.000000
# 75%      35.000000
# max      61.000000
# Name: count_addr, dtype: float64

# %% [markdown]
# Méthodes de classification disponibles :
# *   Quantiles
# *   BoxPlot
# *   EqualInterval
# *   NaturalBreaks
# *   Percentiles
# *   *Jenks
# *   StdMean

# %%
import matplotlib.pyplot as plt

addr_count_quartier['count_addr'].hist(bins=15)
plt.xlabel('Comptage d adresses par quartier')
plt.show()

# %% [markdown]
# **EQUAL INTERVAL** divise les données en classes de taille égale (par exemple, 0-10, 10-20, 20-30, etc.) et fonctionne mieux avec des données qui sont généralement réparties sur toute la plage.
#
# ATTENTION : évitez l'intervalle égal si vos données tendent à une extrémité ou si vous avez une ou deux valeurs aberrantes vraiment importantes.

# %%
mapclassify.EqualInterval(addr_count_quartier.count_addr, k=5)
# Out:
# EqualInterval
#
#    Interval      Count
# ----------------------
# [15.00, 24.20] |    40
# (24.20, 33.40] |    12
# (33.40, 42.60] |    20
# (42.60, 51.80] |     4
# (51.80, 61.00] |     4

# %% [markdown]
# **QUANTILES** essaie de classer le même nombre d'observations dans chacune des N classes. En d'autres termes, cette méthode essaie d'organiser les groupes de façon à ce qu'ils aient la même quantité. Le problème avec les quantiles est que vous pouvez vous retrouver avec des classes qui ont des plages numériques très différentes (par exemple, 1-4, 4-9, 9-250).

# %%
mapclassify.Quantiles(addr_count_quartier.count_addr, k=5)
# Out:
# Quantiles
#
#    Interval      Count
# ----------------------
# [15.00, 17.80] |    16
# (17.80, 21.80] |    16
# (21.80, 31.40] |    16
# (31.40, 38.40] |    16
# (38.40, 61.00] |    16

# %% [markdown]
# **NATURAL BREAKS (Jenks)** organise chaque groupe de manière à ce qu'il y ait moins de variation dans chaque classe ou nuance.
#
# est une sorte de schéma de classification "optimal" qui trouve les ruptures de classe qui minimiseront la variance intra-classe et maximiseront les différences entre les classes. Un inconvénient de cette approche est que chaque ensemble de données génère une solution de classification unique, et si vous avez besoin de faire des comparaisons entre les cartes, comme dans un atlas ou une série (par exemple, une carte pour 1980, 1990, 2000), vous voudrez peut-être utiliser un seul schéma qui peut être appliqué à toutes les cartes.

# %%
mapclassify.NaturalBreaks(addr_count_quartier.count_addr)
# Out:
# NaturalBreaks
#
#    Interval      Count
# ----------------------
# [15.00, 20.00] |    32
# (20.00, 28.00] |    12
# (28.00, 38.00] |    20
# (38.00, 47.00] |    12
# (47.00, 61.00] |     4

# %% [markdown]
# Pour plus d'informations : https://gisgeography.com/choropleth-maps-data-classification/#equal-interval-data-classification

# %%
addr_count_quartier.plot(column='count_addr', scheme='EqualInterval', k=5, figsize=(6, 3), cmap='OrRd', legend=True)
plt.xlabel('EqualInterval')
plt.show()

addr_count_quartier.plot(column='count_addr', scheme='Quantiles', k=5, figsize=(6, 3), cmap='OrRd', legend=True)
plt.xlabel('Quantiles')
plt.show()

addr_count_quartier.plot(column='count_addr', scheme='NaturalBreaks', k=5, figsize=(6, 3), cmap='OrRd', legend=True )
plt.xlabel('NaturalBreaks')
plt.show()

# %%
addr_count_quartier.explore("count_addr", legend=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f30348eadadd1477e1e1a2b62dc87695 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f30348eadadd1477e1e1a2b62dc87695&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f30348eadadd1477e1e1a2b62dc87695 = L.map(
#                 &quot;map_f30348eadadd1477e1e1a2b62dc87695&quot;,
#                 {
#                     center: [48.858869287571764, 2.346919702789453],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f30348eadadd1477e1e1a2b62dc87695);
#
#
#
#
#
#             var tile_layer_ecddab41089a1e3c848be99b797f2304 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f30348eadadd1477e1e1a2b62dc87695);
#
#
#             map_f30348eadadd1477e1e1a2b62dc87695.fitBounds(
#                 [[48.815576667817965, 2.2240784472334783], [48.90216190732557, 2.469760958345428]],
#                 {}
#             );
#
#
#         function geo_json_83ea43281cbf9e1234c86f753975fc96_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;33&quot;: case &quot;56&quot;: case &quot;58&quot;: case &quot;63&quot;: case &quot;75&quot;: case &quot;77&quot;:
#                     return {&quot;color&quot;: &quot;#482677&quot;, &quot;fillColor&quot;: &quot;#482677&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;15&quot;: case &quot;26&quot;: case &quot;76&quot;:
#                     return {&quot;color&quot;: &quot;#48186a&quot;, &quot;fillColor&quot;: &quot;#48186a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;34&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;50&quot;: case &quot;53&quot;: case &quot;59&quot;: case &quot;67&quot;:
#                     return {&quot;color&quot;: &quot;#297b8e&quot;, &quot;fillColor&quot;: &quot;#297b8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;8&quot;: case &quot;54&quot;: case &quot;55&quot;:
#                     return {&quot;color&quot;: &quot;#375b8d&quot;, &quot;fillColor&quot;: &quot;#375b8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;12&quot;: case &quot;24&quot;: case &quot;70&quot;:
#                     return {&quot;color&quot;: &quot;#42be71&quot;, &quot;fillColor&quot;: &quot;#42be71&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;23&quot;: case &quot;64&quot;: case &quot;68&quot;:
#                     return {&quot;color&quot;: &quot;#21a585&quot;, &quot;fillColor&quot;: &quot;#21a585&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;: case &quot;16&quot;: case &quot;22&quot;: case &quot;47&quot;:
#                     return {&quot;color&quot;: &quot;#1e9b8a&quot;, &quot;fillColor&quot;: &quot;#1e9b8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;: case &quot;19&quot;: case &quot;35&quot;: case &quot;60&quot;:
#                     return {&quot;color&quot;: &quot;#2d718e&quot;, &quot;fillColor&quot;: &quot;#2d718e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;69&quot;:
#                     return {&quot;color&quot;: &quot;#21908d&quot;, &quot;fillColor&quot;: &quot;#21908d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;18&quot;: case &quot;27&quot;: case &quot;72&quot;: case &quot;73&quot;:
#                     return {&quot;color&quot;: &quot;#443b84&quot;, &quot;fillColor&quot;: &quot;#443b84&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;21&quot;: case &quot;57&quot;: case &quot;66&quot;: case &quot;71&quot;:
#                     return {&quot;color&quot;: &quot;#2f6c8e&quot;, &quot;fillColor&quot;: &quot;#2f6c8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;25&quot;: case &quot

# %%
#https://pypi.org/project/mapclassify/
# mapclassify implements a family of classification schemes for choropleth maps.

# !pip install mapclassify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.8/dist-packages (2.4.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from mapclassify) (1.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.8/dist-packages (from mapclassify) (1.7.3)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.8/dist-packages (from mapclassify) (1.21.6)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.8/dist-packages (from mapclassify) (1.3.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from mapclassify) (2.6.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->mapclassify) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0->mapclassify) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.0->mapclassify) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->mapclassify) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->mapclassify) (3.1.0)

# %%
import mapclassify
bp = mapclassify.Quantiles(addr_count_quartier.count_addr)
bp
# Out:
# Quantiles
#
#    Interval      Count
# ----------------------
# [15.00, 17.80] |    16
# (17.80, 21.80] |    16
# (21.80, 31.40] |    16
# (31.40, 38.40] |    16
# (38.40, 61.00] |    16

# %% [markdown]
# - faire jointure par adressee 'texte' avec 1903 et faire boolean pour signaler changement de prop,
# - count les points addr dans le polygons dont le boolean "a changé"
# - count groupé par adresse du nombre de propriétaires suppossemenet différents, nouvelle colonne count prop diffrents
# - sum du count point addr dans polygon quartier puis carto thématique

# %%
df_1913 = pd.read_csv(csv_folder + "ptm_1913_augmentee.csv")
print("1913:" + str(len(df_1913)))
print(list(df_1898))
# Out:
# 1913:100832
# ['num_voie', 'code_voie', 'code_voie_quartier', 'nom_voie', 'type_voie', 'quartiers', 'voie_fantome', 'lettre', 'pdf', 'pagination', 'TITRE', 'NUM', 'PART', 'PERS', 'PRENOM', 'ORG', 'STATUT', 'VILLE', 'VOIE', 'RUE', 'NUM_PERS', 'GER', 'LOC', 'SPATIAL', 'my_LETTRE', 'my_NUM', 'my_NUMspe', 'my_Maj', 'my_Id', 'my_Comment', 'test_BIO', 'nb_immeuble', 'list_numImmeuble']
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
